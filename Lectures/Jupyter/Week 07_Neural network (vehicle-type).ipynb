# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import os

# %%
filePath = os.path.join(os.getcwd(), 'datasets', 'vehicle-type.csv')

df = pd.read_csv(filePath)
df.head()
# Out:
#    wheels  chassis  pax   type
# 0      18       25    2  truck
# 1       8       21   24    bus
# 2      18       27    2  truck
# 3       1        1    1   bike
# 4       7       23   21    bus

# %%
x = df.iloc[:, :3]  #wheels, chassis, pax
y = df['type']
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)

# %%
x.head()
# Out:
#    wheels  chassis  pax
# 0      18       25    2
# 1       8       21   24
# 2      18       27    2
# 3       1        1    1
# 4       7       23   21

# %%
y.head()
# Out:
# 0    truck
# 1      bus
# 2    truck
# 3     bike
# 4      bus
# Name: type, dtype: object

# %%
model = MLPClassifier(hidden_layer_sizes=(3, 3), #Hidden1 มี 3 นิวรอน และ Hidden2 มี 3 นิวรอน
                      activation='relu',
                      solver='lbfgs',
                      max_iter=10000,
                      random_state=0)

# %%
model.fit(x_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(3, 3), max_iter=10000, random_state=0,
#               solver='lbfgs')

# %%
predict = model.predict([[10, 20, 2]])
print('Prediction:', predict[0])
print('Score:', model.score(x_test, y_test), '\n')
print('weight:')
print(*model.coefs_, sep='\n')
print()
print('bias:')
print(*model.intercepts_, sep='\n')
# Out:
# Prediction: truck
# Score: 0.7
#
# weight:
# [[ 4.85764024  1.35535732 -3.53727063]
#  [ 0.11854244  0.22445235  2.42030427]
#  [-3.26740285  4.17734159  2.89854417]]
# [[ 1.67657548  0.04957034 -3.1155931 ]
#  [-2.21370784 -3.21284237  1.31425089]
#  [ 1.28697617  0.4790104   2.47103003]]
# [[-2.24745298 -0.619289    0.98646091  1.59657209]
#  [-0.87873784 -1.06794617  0.90215541  0.99895943]
#  [ 3.56520814  3.64034096 -3.7833863  -4.04755722]]
#
# bias:
# [-0.97598852  2.42639085  1.06364849]
# [ 0.33248934 -1.12211985  1.71698724]
# [ 2.93096011 -7.17025575 11.61652475 -5.79482092]
# c:\Program Files\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(

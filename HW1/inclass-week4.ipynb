# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('inclass-data/adult.data', header=None)
df.columns = ['age', 'workclass', 'fnlwgt', 'edu', 'edu-num', 'marital', 'occupation', 'relationship', 'race', 'sex', 'cap-gain', 'cap-loss','hpw','native country','income']
df.head()
# Out:
#    age          workclass  fnlwgt         edu  edu-num              marital  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
# 3   53            Private  234721        11th        7   Married-civ-spouse
# 4   28            Private  338409   Bachelors       13   Married-civ-spouse
#
#            occupation    relationship    race      sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White     Male      2174         0
# 1     Exec-managerial         Husband   White     Male         0         0
# 2   Handlers-cleaners   Not-in-family   White     Male         0         0
# 3   Handlers-cleaners         Husband   Black     Male         0         0
# 4      Prof-specialty            Wife   Black   Female         0         0
#
#    hpw  native country  income
# 0   40   United-States   <=50K
# 1   13   United-States   <=50K
# 2   40   United-States   <=50K
# 3   40   United-States   <=50K
# 4   40            Cuba   <=50K

# %% [markdown]
# ## Drop useless features (columns)

# %%
df = df.drop(columns=['fnlwgt', 'edu', 'cap-gain', 'cap-loss', 'native country'])

# %%
df['age'].value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: age, Length: 73, dtype: int64

# %%
df.head()
# Out:
#    age          workclass  edu-num              marital          occupation  \
# 0   39          State-gov       13        Never-married        Adm-clerical
# 1   50   Self-emp-not-inc       13   Married-civ-spouse     Exec-managerial
# 2   38            Private        9             Divorced   Handlers-cleaners
# 3   53            Private        7   Married-civ-spouse   Handlers-cleaners
# 4   28            Private       13   Married-civ-spouse      Prof-specialty
#
#      relationship    race      sex  hpw  income
# 0   Not-in-family   White     Male   40   <=50K
# 1         Husband   White     Male   13   <=50K
# 2   Not-in-family   White     Male   40   <=50K
# 3         Husband   Black     Male   40   <=50K
# 4            Wife   Black   Female   40   <=50K

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
# remove the ? from the all column
for i in df.columns:
    dfi_nc = df[df[i] == ' ?'].index
    df = df.drop(labels=dfi_nc)

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
# Name: workclass, dtype: int64

# %%
df['income'].value_counts()
# Out:
#  <=50K    23068
#  >50K      7650
# Name: income, dtype: int64

# %%
df['hpw'].value_counts()
# Out:
# 40    14525
# 50     2763
# 45     1791
# 60     1441
# 35     1203
#       ...
# 82        1
# 94        1
# 92        1
# 87        1
# 74        1
# Name: hpw, Length: 94, dtype: int64

# %%
df['hpw'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
# Find the index of the rows with hpw == 1
df[df['hpw'] == 1].index
# Out:
# Int64Index([189, 1036, 11451, 19750, 20909, 22960, 24284, 25078], dtype='int64')

# %%
# %%timeit
# Find the index of the rows where hpw count is 1 : Method 1
df.groupby("hpw").filter(lambda x: len(x) <= 5)
# Out:
#        age          workclass  edu-num                 marital  \
# 729     65   Self-emp-not-inc        7      Married-civ-spouse
# 1243    65   Self-emp-not-inc        9      Married-civ-spouse
# 3426    39          Local-gov       12                Divorced
# 3876    61            Private        4      Married-civ-spouse
# 6380    33            Private        9           Never-married
# 6390    44   Self-emp-not-inc        7      Married-civ-spouse
# 6401    55            Private       13                Divorced
# 7142    48            Private        9      Married-civ-spouse
# 7678    31          Local-gov       13      Married-civ-spouse
# 8218    65            Private        9                Divorced
# 8733    25            Private       14           Never-married
# 9124    33   Self-emp-not-inc        9      Married-civ-spouse
# 10377   44       Self-emp-inc        9      Married-civ-spouse
# 10499   56   Self-emp-not-inc        3      Married-civ-spouse
# 10728   61            Private        9                Divorced
# 11503   29            Private        9      Married-civ-spouse
# 13336   47   Self-emp-not-inc       10      Married-civ-spouse
# 14642   62            Private        4      Married-civ-spouse
# 14767   39            Private        9                Divorced
# 15008   25            Private        2      Married-civ-spouse
# 15341   31            Private       14      Married-civ-spouse
# 16931   27            Private       10      Married-civ-spouse
# 17613   51       Self-emp-inc        9                Divorced
# 19140   45            Private        7                Divorced
# 19160   36   Self-emp-not-inc       10      Married-civ-spouse
# 19576   53   Self-emp-not-inc        2      Married-civ-spouse
# 20465   39            Private       15      Married-civ-spouse
# 21338   35          Local-gov       10      Married-civ-spouse
# 21852   31   Self-emp-not-inc        9      Married-civ-spouse
# 23519   46          Local-gov        9      Married-civ-spouse
# 23628   72   Self-emp-not-inc       10      Married-civ-spouse
# 24576   52   Self-emp-not-inc       10      Married-civ-spouse
# 24675   47       Self-emp-inc       12                 Widowed
# 24869   37   Self-emp-not-inc        9           Never-married
# 25926   48          State-gov       14      Married-civ-spouse
# 25975   42            Private       12   Married-spouse-absent
# 26935   48            Private        7                Divorced
# 27594   26            Private        9      Married-civ-spouse
# 28366   30            Private        9      Married-civ-spouse
# 28442   33            Private        3      Married-civ-spouse
# 28479   25            Private        9           Never-married
# 29263   41       Self-emp-inc       10      Married-civ-spouse
# 29775   42   Self-emp-not-inc        9      Married-civ-spouse
# 32259   63            Private        6                 Widowed
# 32364   45            Private       11      Married-civ-spouse
# 32391   55            Private        9               Separated
# 32402   42            Private       10      Married-civ-spouse
#
#                occupation    relationship                 race      sex  hpw  \
# 729       Exec-managerial         Husband                White     Male   59
# 1243      Exec-managerial         Husband                White     Male   59
# 3426       Prof-specialty   Not-in-family                White     Male   59
# 3876     Transport-moving         Husband                White     Male   31
# 6380     Transport-moving   Not-in-family                White     Male   87
# 6390      Farming-fishing         Husband                White     Male   88
# 6401         Adm-clerical       Unmarried                White   Female   73
# 7142         Tech-support         Husband                White     Male   89
# 7678      Protective-serv         Husband                White     Male   97
# 8218         Adm-clerical       Unmarried                White   Female   59
# 8733       Prof-specialty       Own-child                White   Female   31
# 9124      Farming-fishing         Husband                White     Male   94
# 10377    Transport-moving         Husband                White     Male   96
# 10499     Exec-managerial         Husband                White     Male   67
# 10728     Farming-fishing   Not-in-family                White   Female   82
# 11503     Farming-fishing         Husband                White     Male   97
# 13336     Farming-fishing         Husband                White     Male   86
# 14642     Protective-serv         Husband                White     Male   91
# 14767       Other-service       Unmarried                White   Female   81
# 15008     Farming-fishing         Husband                White     Male   96
# 15341               Sales         Husband                White     Male   76
# 16931      Prof-specialty         Husband                White     Male   88
# 17613     Protective-serv   Not-in-family                White     Male   81
# 19140    Transport-moving   Not-in-family                White     Male   76
# 19160               Sales         Husband                White     Male   92
# 19576     Exec-managerial         Husband                White     Male   67
# 20465      Prof-specialty         Husband   Asian-Pac-Islander     Male   67
# 21338     Protective-serv         Husband                White     Male   61
# 21852     Farming-fishing         Husband                White     Male   91
# 23519     Protective-serv         Husband                White     Male   96
# 23628     Farming-fishing         Husband                White     Male   74
# 24576     Exec-managerial         Husband                White     Male   95
# 24675     Exec-managerial   Not-in-family                White   Female   67
# 24869     Farming-fishing   Not-in-family                White     Male   86
# 25926      Prof-specialty         Husband                White     Male   61
# 25975     Exec-managerial       Unmarried   Asian-Pac-Islander   Female   31
# 26935       Other-service   Not-in-family                White   Female   31
# 27594   Machine-op-inspct         Husband                White     Male   96
# 28366    Transport-moving         Husband                White     Male   73
# 28442       Other-service         Husband                White     Male   59
# 28479   Handlers-cleaners       Own-child                White     Male   95
# 29263               Sales         Husband                White     Male   91
# 29775    Transport-moving         Husband                White     Male   96
# 32259       Other-service   Not-in-family                White   Female   31
# 32364        Craft-repair         Husband                White     Male   76
# 32391     Protective-serv   Not-in-family                White     Male   81
# 32402        Craft-repair         Husband                White     Male   89
#
#        income
# 729      >50K
# 1243     >50K
# 3426    <=50K
# 3876    <=50K
# 6380    <=50K
# 6390    <=50K
# 6401    <=50K
# 7142    <=50K
# 7678     >50K
# 8218    <=50K
# 8733    <=50K
# 9124    <=50K
# 10377   <=50K
# 10499    >50K
# 10728   <=50K
# 11503   <=50K
# 13336   <=50K
# 14642   <=50K
# 14767   <=50K
# 15008   <=50K
# 15341    >50K
# 16931   <=50K
# 17613   <=50K
# 19140    >50K
# 19160   <=50K
# 19576    >50K
# 20465    >50K
# 21338    >50K
# 21852   <=50K
# 23519    >50K
# 23628   <=50K
# 24576    >50K
# 24675   <=50K
# 24869   <=50K
# 25926    >50K
# 25975   <=50K
# 26935   <=50K
# 27594   <=50K
# 28366    >50K
# 28442   <=50K
# 28479   <=50K
# 29263   <=50K
# 29775   <=50K
# 32259   <=50K
# 32364   <=50K
# 32391   <=50K
# 32402    >50K

# %%
# %%timeit
df[df.groupby("hpw")["hpw"].transform('size') > 5]
# Out:
#        age          workclass  edu-num              marital  \
# 0       39          State-gov       13        Never-married
# 1       50   Self-emp-not-inc       13   Married-civ-spouse
# 2       38            Private        9             Divorced
# 3       53            Private        7   Married-civ-spouse
# 4       28            Private       13   Married-civ-spouse
# ...    ...                ...      ...                  ...
# 32556   27            Private       12   Married-civ-spouse
# 32557   40            Private        9   Married-civ-spouse
# 32558   58            Private        9              Widowed
# 32559   22            Private        9        Never-married
# 32560   52       Self-emp-inc        9   Married-civ-spouse
#
#                occupation    relationship    race      sex  hpw  income
# 0            Adm-clerical   Not-in-family   White     Male   40   <=50K
# 1         Exec-managerial         Husband   White     Male   13   <=50K
# 2       Handlers-cleaners   Not-in-family   White     Male   40   <=50K
# 3       Handlers-cleaners         Husband   Black     Male   40   <=50K
# 4          Prof-specialty            Wife   Black   Female   40   <=50K
# ...                   ...             ...     ...      ...  ...     ...
# 32556        Tech-support            Wife   White   Female   38   <=50K
# 32557   Machine-op-inspct         Husband   White     Male   40    >50K
# 32558        Adm-clerical       Unmarried   White   Female   40   <=50K
# 32559        Adm-clerical       Own-child   White     Male   20   <=50K
# 32560     Exec-managerial            Wife   White   Female   40    >50K
#
# [30671 rows x 10 columns]

# %%
# %%timeit
df = df[df['hpw'].map(df['hpw'].value_counts()) > 5]

# %%
from scipy import stats
df = df[(np.abs(stats.zscore(df['age'])) < 3)]
stats.zscore(df['hpw'])
# Out:
# 0       -0.078890
# 1       -2.356220
# 2       -0.078890
# 3       -0.078890
# 4       -0.078890
#            ...
# 32556   -0.247581
# 32557   -0.078890
# 32558   -0.078890
# 32559   -1.765801
# 32560   -0.078890
# Name: hpw, Length: 30549, dtype: float64

# %%
import sklearn
from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, Normalizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV

numeric_features = ["age", "edu-num", "hpw"]
numeric_transformer = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="median")), ("scaler", StandardScaler())]
)

categorical_features = ["workclass", "marital", "occupation","relationship","race"]
categorical_transformer = OneHotEncoder(handle_unknown="ignore")

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

clf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", LogisticRegression())]
)

# %%
df.head()
# Out:
#    age          workclass  edu-num              marital          occupation  \
# 0   39          State-gov       13        Never-married        Adm-clerical
# 1   50   Self-emp-not-inc       13   Married-civ-spouse     Exec-managerial
# 2   38            Private        9             Divorced   Handlers-cleaners
# 3   53            Private        7   Married-civ-spouse   Handlers-cleaners
# 4   28            Private       13   Married-civ-spouse      Prof-specialty
#
#      relationship    race      sex  hpw  income
# 0   Not-in-family   White     Male   40   <=50K
# 1         Husband   White     Male   13   <=50K
# 2   Not-in-family   White     Male   40   <=50K
# 3         Husband   Black     Male   40   <=50K
# 4            Wife   Black   Female   40   <=50K

# %%
x = df.iloc[:,:-1]    #Split only data
y = df.iloc[:,-1]     #Split the target out

x_new  = preprocessor.fit_transform(x)
# Out:
#        age          workclass  edu-num              marital  \
# 0       39          State-gov       13        Never-married
# 1       50   Self-emp-not-inc       13   Married-civ-spouse
# 2       38            Private        9             Divorced
# 3       53            Private        7   Married-civ-spouse
# 4       28            Private       13   Married-civ-spouse
# ...    ...                ...      ...                  ...
# 32556   27            Private       12   Married-civ-spouse
# 32557   40            Private        9   Married-civ-spouse
# 32558   58            Private        9              Widowed
# 32559   22            Private        9        Never-married
# 32560   52       Self-emp-inc        9   Married-civ-spouse
#
#                occupation    relationship    race      sex  hpw
# 0            Adm-clerical   Not-in-family   White     Male   40
# 1         Exec-managerial         Husband   White     Male   13
# 2       Handlers-cleaners   Not-in-family   White     Male   40
# 3       Handlers-cleaners         Husband   Black     Male   40
# 4          Prof-specialty            Wife   Black   Female   40
# ...                   ...             ...     ...      ...  ...
# 32556        Tech-support            Wife   White   Female   38
# 32557   Machine-op-inspct         Husband   White     Male   40
# 32558        Adm-clerical       Unmarried   White   Female   40
# 32559        Adm-clerical       Own-child   White     Male   20
# 32560     Exec-managerial            Wife   White   Female   40
#
# [30549 rows x 9 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x_new,y,test_size = 0.1,random_state = 0)

# %%
# let's print the shape before we reshape and normalize
print("X_train shape", x_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", x_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (27494, 42)
# y_train shape (27494,)
# X_test shape (3055, 42)
# y_test shape (3055,)

# %%
#Build logistic regression model
clf = LogisticRegression()
clf.fit(x_train,y_train)
# = theta0 + theta1*x _theta2*y
print("Theta0: ",clf.intercept_[0])
print("Theta1: ",clf.coef_[0][0])
print("Theta2: ",clf.coef_[0][1])
print("0 = {:.4f}+{:.4f}x+{:.4f}y".format(clf.intercept_[0],clf.coef_[0][0],clf.coef_[0][1]))
# Out:
# Theta0:  -2.553927422492789
# Theta1:  0.4051112693886674
# Theta2:  0.7648331571361858
# 0 = -2.5539+0.4051x+0.7648y
# c:\program files\python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_pred = clf.predict(x_train)

# Classification report
from sklearn.metrics import classification_report,confusion_matrix

print("Classification report \n=======================")
print(classification_report(y_true=y_train, y_pred=y_pred))
print("Confusion matrix \n=======================")

print(confusion_matrix(y_true=y_train, y_pred=y_pred))
# Out:
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.92      0.89     20633
#         >50K       0.70      0.56      0.62      6861
#
#     accuracy                           0.83     27494
#    macro avg       0.78      0.74      0.76     27494
# weighted avg       0.82      0.83      0.82     27494
#
# Confusion matrix
# =======================
# [[18954  1679]
#  [ 3014  3847]]

# %%
# Plot confusion matrix of training set
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(clf,
                      x_train,
                      y_train,
                      display_labels=list(set(y_test)),
                      cmap=plt.cm.Blues) 
plt.title('Confusion matrix of training set')
plt.show()
# Out:
# c:\program files\python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print("model score: %.3f" % clf.score(x_test, y_test))
# Out:
# model score: 0.841
